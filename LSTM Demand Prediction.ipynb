# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
import seaborn as sns

from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras import regularizers
# Out:
# Using TensorFlow backend.

# %%
pd.options.display.max_columns = None

# %% [markdown]
# ### Importing Data

# %%
raw_data = pd.read_csv("F:\\Learning\\Bsc.IT(Hon)\\Semester 8\\ML\\Lab\\Hotel Prediction\\Hotel Data\\H1.csv")
df = raw_data.copy()

# %%
df
# Out:
#        IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0               0       342             2015             July
# 1               0       737             2015             July
# 2               0         7             2015             July
# 3               0        13             2015             July
# 4               0        14             2015             July
# ...           ...       ...              ...              ...
# 40055           0       212             2017           August
# 40056           0       169             2017           August
# 40057           0       204             2017           August
# 40058           0       211             2017           August
# 40059           0       161             2017           August
#
#        ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                         27                      1                     0
# 1                         27                      1                     0
# 2                         27                      1                     0
# 3                         27                      1                     0
# 4                         27                      1                     0
# ...                      ...                    ...                   ...
# 40055                     35                     31                     2
# 40056                     35                     30                     2
# 40057                     35                     29                     4
# 40058                     35                     31                     4
# 40059                     35                     31                     4
#
#        StaysInWeekNights  Adults  Children  Babies       Meal Country  \
# 0                      0       2         0       0  BB            PRT
# 1                      0       2         0       0  BB            PRT
# 2                      1       1         0       0  BB            GBR
# 3                      1       1         0       0  BB            GBR
# 4                      2       2         0       0  BB            GBR
# ...                  ...     ...       ...     ...        ...     ...
# 40055                  8       2         1       0  BB            GBR
# 40056                  9       2         0       0  BB            IRL
# 40057                 10       2         0       0  BB            IRL
# 40058                 10       2         0       0  HB            GBR
# 40059                 10       2         0       0  HB            DEU
#
#        MarketSegment DistributionChannel  IsRepeatedGuest  \
# 0             Direct              Direct                0
# 1             Direct              Direct                0
# 2             Direct              Direct                0
# 3          Corporate           Corporate                0
# 4          Online TA               TA/TO                0
# ...              ...                 ...              ...
# 40055  Offline TA/TO               TA/TO                0
# 40056         Direct              Direct                0
# 40057         Direct              Direct                0
# 40058  Offline TA/TO               TA/TO                0
# 40059  Offline TA/TO               TA/TO                0
#
#        PreviousCancellations  PreviousBookingsNotCanceled  ReservedRoomType  \
# 0                          0                            0  C
# 1                          0                            0  C
# 2                          0                            0  A
# 3                          0                            0  A
# 4                          0                            0  A
# ...                      ...                          ...               ...
# 40055                      0                            0  A
# 40056                      0                            0  E
# 40057                      0                            0  E
# 40058                      0                            0  D
# 40059                      0                            0  A
#
#        AssignedRoomType  BookingChanges      DepositType        Agent  \
# 0      C                              3  No Deposit              NULL
# 1      C                              4  No Deposit              NULL
# 2      C                              0  No Deposit              NULL
# 3      A                              0  No Deposit               304
# 4      A                              0  No Deposit               240
# ...                 ...             ...              ...          ...
# 40055  A                              1  No Deposit               143
# 40056  E                              0  No Deposit               250
# 40057  E                              0  No Deposit               250
# 40058  D                              0  No Deposit                40
# 40059  A                              0  No Deposit                69
#
#            Company  DaysInWaitingList     CustomerType     ADR  \
# 0             NULL                  0        Transient    0.00
# 1             NULL                  0        Transient    0.00
# 2             NULL                  0        Transient   75.00
# 3             NULL                  0        Transient   75.00
# 4             NULL                  0        Transient   98.00
# ...            ...                ...              ...     ...
# 40055         NULL                  0        Transient   89.75
# 40056         NULL                  0  Transient-Party  202.27
# 40057         NULL                  0        Transient  153.57
# 40058         NULL                  0         Contract  112.80
# 40059         NULL                  0        Transient   99.06
#
#        RequiredCarParkingSpaces  TotalOfSpecialRequests ReservationStatus  \
# 0                             0                       0         Check-Out
# 1                             0                       0         Check-Out
# 2                             0                       0         Check-Out
# 3                             0                       0         Check-Out
# 4                             0                       1         Check-Out
# ...                         ...                     ...               ...
# 40055                         0                       0         Check-Out
# 40056                         0                       1         Check-Out
# 40057                         0                       3         Check-Out
# 40058                         0                       1         Check-Out
# 40059                         0                       0         Check-Out
#
#       ReservationStatusDate
# 0                2015-07-01
# 1                2015-07-01
# 2                2015-07-02
# 3                2015-07-02
# 4                2015-07-03
# ...                     ...
# 40055            2017-09-10
# 40056            2017-09-10
# 40057            2017-09-12
# 40058            2017-09-14
# 40059            2017-09-14
#
# [40060 rows x 31 columns]

# %%
df.columns
# Out:
# Index(['IsCanceled', 'LeadTime', 'ArrivalDateYear', 'ArrivalDateMonth',
#        'ArrivalDateWeekNumber', 'ArrivalDateDayOfMonth',
#        'StaysInWeekendNights', 'StaysInWeekNights', 'Adults', 'Children',
#        'Babies', 'Meal', 'Country', 'MarketSegment', 'DistributionChannel',
#        'IsRepeatedGuest', 'PreviousCancellations',
#        'PreviousBookingsNotCanceled', 'ReservedRoomType', 'AssignedRoomType',
#        'BookingChanges', 'DepositType', 'Agent', 'Company',
#        'DaysInWaitingList', 'CustomerType', 'ADR', 'RequiredCarParkingSpaces',
#        'TotalOfSpecialRequests', 'ReservationStatus', 'ReservationStatusDate'],
#       dtype='object')

# %%
df.ReservedRoomType.value_counts()
# Out:
# A                   23399
# D                    7433
# E                    4982
# G                    1610
# F                    1106
# C                     918
# H                     601
# L                       6
# B                       3
# P                       2
# Name: ReservedRoomType, dtype: int64

# %%
df.AssignedRoomType.value_counts()
# Out:
# A                   17046
# D                   10339
# E                    5638
# C                    2214
# G                    1853
# F                    1733
# H                     712
# I                     363
# B                     159
# P                       2
# L                       1
# Name: AssignedRoomType, dtype: int64

# %% [markdown]
# ### Ordering Months

# %%
months = ["January", "February", "March", "April", "May", "June", 
          "July", "August", "September", "October", "November", "December"]
df['ArrivalDateMonth'] = pd.Categorical(df['ArrivalDateMonth'], categories=months, ordered=True)

# %% [markdown]
# ### Per RoomType, Per CustomerSegment vs Demand

# %%
pred_df = df.pivot_table( index = ['ArrivalDateYear','ArrivalDateWeekNumber'], aggfunc='count', values='ADR', columns=['AssignedRoomType','MarketSegment'])
pred_df = pred_df.fillna(0)

# %%
pred_df
# Out:
# AssignedRoomType                      A                                  \
# MarketSegment                            Complementary Corporate Direct
# ArrivalDateYear ArrivalDateWeekNumber
# 2015            27                                 0.0       1.0    6.0
#                 28                                 0.0       5.0   19.0
#                 29                                 0.0       3.0   14.0
#                 30                                 0.0       3.0   20.0
#                 31                                 0.0       1.0   12.0
# ...                                                ...       ...    ...
# 2017            31                                 0.0       1.0   26.0
#                 32                                 0.0       1.0   21.0
#                 33                                 0.0       2.0   26.0
#                 34                                 0.0       2.0   12.0
#                 35                                 2.0       0.0   12.0
#
# AssignedRoomType                                                      \
# MarketSegment                         Groups Offline TA/TO Online TA
# ArrivalDateYear ArrivalDateWeekNumber
# 2015            27                       0.0          26.0      31.0
#                 28                       0.0          38.0      49.0
#                 29                      34.0          42.0      64.0
#                 30                       0.0          40.0      58.0
#                 31                       0.0          48.0      64.0
# ...                                      ...           ...       ...
# 2017            31                       0.0          28.0     111.0
#                 32                       0.0          33.0      93.0
#                 33                       0.0          32.0     124.0
#                 34                       0.0          43.0      97.0
#                 35                       0.0          16.0      79.0
#
# AssignedRoomType                      B                               \
# MarketSegment                                Corporate Direct Groups
# ArrivalDateYear ArrivalDateWeekNumber
# 2015            27                                 1.0    0.0    0.0
#                 28                                 0.0    0.0    0.0
#                 29                                 0.0    0.0    0.0
#                 30                                 0.0    1.0    0.0
#                 31                                 0.0    1.0    0.0
# ...                                                ...    ...    ...
# 2017            31                                 1.0    0.0    0.0
#                 32                                 0.0    0.0    0.0
#                 33                                 1.0    1.0    0.0
#                 34                                 0.0    0.0    0.0
#                 35                                 0.0    0.0    0.0
#
# AssignedRoomType                                               \
# MarketSegment                         Offline TA/TO Online TA
# ArrivalDateYear ArrivalDateWeekNumber
# 2015            27                              1.0       0.0
#                 28                              1.0       0.0
#                 29                              0.0       2.0
#                 30                              0.0       0.0
#                 31                              0.0       0.0
# ...                                             ...       ...
# 2017            31                              0.0       2.0
#                 32                              0.0       2.0
#                 33                              0.0       4.0
#                 34                              0.0       1.0
#                 35                              1.0       0.0
#
# AssignedRoomType                      C                                  \
# MarketSegment                            Complementary Corporate Direct
# ArrivalDateYear ArrivalDateWeekNumber
# 2015            27                                 0.0       1.0    7.0
#                 28                                 0.0       0.0    7.0
#                 29                                 0.0       4.0    8.0
#                 30                                 0.0       0.0    7.0
#                 31                                 0.0       0.0    9.0
# ...                                                ...       ...    ...
# 2017            31                                 0.0       0.0    4.0
#                 32                                 0.0       0.0   10.0
#                 33                                 0.0       0.0    8.0
#                 34                                 0.0       0.0    3.0
#                 35                                 0.0       0.0    7.0
#
# AssignedRoomType                                                      \
# MarketSegment                         Groups Offline TA/TO Online TA
# ArrivalDateYear ArrivalDateWeekNumber
# 2015            27                       0.0           4.0      12.0
#                 28                       0.0           2.0      13.0
#                 29                       6.0           1.0       9.0
#                 30                       0.0           3.0       7.0
#                 31                       0.0           2.0      10.0
# ...                                      ...           ...       ...
# 2017            31                       0.0           2.0      23.0
#                 32                       0.0           0.0      21.0
#                 33                       0.0           1.0      18.0
#                 34                       0.0           2.0      28.0
#                 35                       0.0           0.0      15.0
#
# AssignedRoomType                      D                                  \
# MarketSegment                            Complementary Corporate Direct
# ArrivalDateYear ArrivalDateWeekNumber
# 2015            27                                 0.0       0.0    5.0
#                 28                                 0.0       0.0    4.0
#                 29                                 0.0       0.0   16.0
#                 30                                 0.0       0.0   12.0
#                 31                                 0.0       0.0    9.0
# ...                                                ...       ...    ...
# 2017            31                                 0.0       4.0   14.0
#                 32                                 0.0       0.0   25.0
#                 33                                 0.0       1.0   12.0
#                 34                                 0.0       0.0   13.0
#                 35                                 0.0       0.0   12.0
#
# AssignedRoomType                                                      \
# MarketSegment                         Groups Offline TA/TO Online TA
# ArrivalDateYear ArrivalDateWeekNumber
# 2015            27                       0.0          15.0      13.0
#                 28                       0.0          32.0      17.0
#                 29                       3.0          21.0      33.0
#                 30                       0.0          18.0      44.0
#                 31                       0.0          22.0      62.0
# ...                                      ...           ...       ...
# 2017            31                       0.0          16.0      68.0
#                 32                       0.0          24.0      52.0
#                 33                       0.0          22.0      62.0
#                 34                       0.0          24.0      44.0
#                 35                       0.0          38.0      19.0
#
# AssignedRoomType                      E                                  \
# MarketSegment                            Complementary Corporate Direct
# ArrivalDateYear ArrivalDateWeekNumber
# 2015            27                                 0.0       0.0    5.0
#                 28                                 0.0       0.0   11.0
#                 29                                 0.0       0.0   17.0
#                 30                                 0.0       0.0   14.0
#                 31                                 0.0       0.0    8.0
# ...                                                ...       ...    ...
# 2017            31                                 0.0       2.0    9.0
#                 32                                 0.0       1.0   16.0
#                 33                                 1.0       0.0    9.0
#                 34                                 1.0       0.0    9.0
#                 35                                 0.0       0.0    6.0
#
# AssignedRoomType                                                      \
# MarketSegment                         Groups Offline TA/TO Online TA
# ArrivalDateYear ArrivalDateWeekNumber
# 2015            27                       0.0           7.0      15.0
#                 28                       0.0           8.0      28.0
#                 29                       1.0           7.0      18.0
#                 30                       0.0          10.0      33.0
#                 31                       0.0          13.0      28.0
# ...                                      ...           ...       ...
# 2017            31                       0.0           8.0      48.0
#                 32                       0.0          10.0      30.0
#                 33                       0.0           6.0      41.0
#                 34                       0.0           7.0      45.0
#                 35                       0.0          15.0      24.0
#
# AssignedRoomType                      F                                  \
# MarketSegment                            Complementary Corporate Direct
# ArrivalDateYear ArrivalDateWeekNumber
# 2015            27                                 0.0       0.0    3.0
#                 28                                 0.0       1.0    5.0
#                 29                                 0.0       0.0    5.0
#                 30                                 0.0       1.0    2.0
#                 31                                 0.0       0.0   13.0
# ...                                                ...       ...    ...
# 2017            31                                 0.0       0.0   12.0
#                 32                                 0.0       0.0    7.0
#                 33                                 0.0       0.0   10.0
#                 34                                 0.0       0.0   12.0
#                 35                                 0.0       0.0    5.0
#
# AssignedRoomType                                                      \
# MarketSegment                         Groups Offline TA/TO Online TA
# ArrivalDateYear ArrivalDateWeekNumber
# 2015            27                       0.0           1.0       5.0
#                 28                       0.0           0.0       7.0
#                 29                       1.0           1.0      10.0
#                 30                       0.0           5.0       8.0
#                 31                       0.0           3.0       7.0
# ...                                      ...           ...       ...
# 2017            31                       0.0           1.0       5.0
#                 32                       0.0           0.0       6.0
#                 33                       0.0           0.0      20.0
#                 34                       0.0           0.0       6.0
#                 35                       0.0           0.0       7.0
#
# AssignedRoomType                      G                                  \
# MarketSegment                            Complementary Corporate Direct
# ArrivalDateYear ArrivalDateWeekNumber
# 2015            27                                 0.0       1.0    5.0
#                 28                                 0.0       0.0    7.0
#                 29                                 0.0       0.0    7.0
#                 30                                 0.0       0.0    8.0
#                 31                                 0.0       0.0    5.0
# ...                                                ...       ...    ...
# 2017            31                                 0.0       0.0    4.0
#                 32                                 0.0       0.0    3.0
#                 33                                 0.0       0.0    5.0
#                 34                                 0.0       0.0    6.0
#                 35                                 0.0       0.0    2.0
#
# AssignedRoomType                                                      \
# MarketSegment                         Groups Offline TA/TO Online TA
# ArrivalDateYear ArrivalDateWeekNumber
# 2015            27                       0.0           0.0       6.0
#                 28                       0.0           0.0      10.0
#                 29                       0.0           0.0       7.0
#                 30                       0.0           0.0      15.0
#                 31                       0.0           0.0      15.0
# ...                                      ...           ...       ...
# 2017            31                       0.0           1.0      17.0
#                 32                       0.0           0.0      22.0
#                 33                       0.0           0.0      23.0
#                 34                       0.0           0.0      16.0
#                 35                       0.0           0.0      12.0
#
# AssignedRoomType                      H                                  \
# MarketSegment                            Complementary Corporate Direct
# ArrivalDateYear ArrivalDateWeekNumber
# 2015            27                                 1.0       0.0    1.0
#                 28                                 0.0       0.0    2.0
#                 29                                 0.0       0.0    3.0
#                 30                                 0.0       0.0    0.0
#                 31                                 0.0       1.0    3.0
# ...                                                ...       ...    ...
# 2017            31                                 0.0       0.0    4.0
#                 32                                 0.0       0.0    3.0
#                 33                                 0.0       0.0    3.0
#                 34                                 0.0       0.0    2.0
#                 35                                 0.0       0.0    2.0
#
# AssignedRoomType                                                      \
# MarketSegment                         Groups Offline TA/TO Online TA
# ArrivalDateYear ArrivalDateWeekNumber
# 2015            27                       0.0           0.0       3.0
#                 28                       0.0           0.0       5.0
#                 29                       0.0           0.0       3.0
#                 30                       0.0           0.0       4.0
#                 31                       0.0           1.0       6.0
# ...                                      ...           ...       ...
# 2017            31                       0.0           1.0       6.0
#                 32                       0.0           0.0       6.0
#                 33                       0.0           0.0      12.0
#                 34                       0.0           0.0       7.0
#                 35                       0.0           0.0       2.0
#
# AssignedRoomType                      I                                  \
# MarketSegment                            Complementary Corporate Direct
# ArrivalDateYear ArrivalDateWeekNumber
# 2015            27                                 0.0       0.0    0.0
#                 28                                 0.0       0.0    0.0
#                 29                                 0.0       0.0    0.0
#                 30                                 0.0       0.0    0.0
#                 31                                 0.0       0.0    0.0
# ...                                                ...       ...    ...
# 2017            31                                 0.0       0.0    3.0
#                 32                                 0.0       0.0    0.0
#                 33                                 0.0       0.0    2.0
#                 34                                 0.0       0.0    0.0
#                 35                                 0.0       0.0    0.0
#
# AssignedRoomType                                                      \
# MarketSegment                         Groups Offline TA/TO Online TA
# ArrivalDateYear ArrivalDateWeekNumber
# 2015            27                       0.0           1.0       0.0
#                 28                       0.0           0.0       0.0
#                 29                       0.0           0.0       0.0
#                 30                       0.0           1.0       3.0
#                 31                       0.0           2.0       2.0
# ...                                      ...           ...       ...
# 2017            31                       0.0           1.0       0.0
#                 32                       0.0           0.0       2.0
#                 33                       0.0           0.0       0.0
#                 34                       0.0           2.0       1.0
#                 35                       0.0           0.0       1.0
#
# AssignedRoomType                      L                P
# MarketSegment                                   Direct    Offline TA/TO
# ArrivalDateYear ArrivalDateWeekNumber
# 2015            27                                 0.0              0.0
#                 28                                 0.0              0.0
#                 29                                 1.0              0.0
#                 30                                 0.0              0.0
#                 31                                 0.0              0.0
# ...                                                ...              ...
# 2017            31                                 0.0              0.0
#                 32                                 0.0              0.0
#                 33                                 0.0              0.0
#                 34                                 0.0              0.0
#                 35                                 0.0              0.0
#
# [115 rows x 55 columns]

# %% [raw]
# pred_df.columns

# %%
selected_col = pred_df.columns[5]

# %%
pred_df[selected_col]
# Out:
# ArrivalDateYear  ArrivalDateWeekNumber
# 2015             27                        31.0
#                  28                        49.0
#                  29                        64.0
#                  30                        58.0
#                  31                        64.0
#                                           ...
# 2017             31                       111.0
#                  32                        93.0
#                  33                       124.0
#                  34                        97.0
#                  35                        79.0
# Name: (A               , Online TA), Length: 115, dtype: float64

# %%
df_lstm = pred_df[selected_col]
df_lstm.shape
# Out:
# (115,)

# %%
df_lstm.plot(figsize=(16,10))

# %% [markdown]
# #### Adding ADR

# %%
col_ADR = df.pivot_table( index = ['ArrivalDateYear','ArrivalDateWeekNumber'], aggfunc='mean', values='ADR', columns=['AssignedRoomType','MarketSegment'])
col_ADR = pred_df.fillna(0)

# %%
col_ADR = col_ADR[selected_col]

# %%
col_ADR
# Out:
# ArrivalDateYear  ArrivalDateWeekNumber
# 2015             27                        31.0
#                  28                        49.0
#                  29                        64.0
#                  30                        58.0
#                  31                        64.0
#                                           ...
# 2017             31                       111.0
#                  32                        93.0
#                  33                       124.0
#                  34                        97.0
#                  35                        79.0
# Name: (A               , Online TA), Length: 115, dtype: float64

# %% [markdown]
# ### Joining Columns

# %%
new_df = pd.DataFrame(df_lstm)
new_df['ADR'] = col_ADR

# %%
new_df = new_df.reset_index()

# %%
new_df.columns = ['Year', 'Week', 'Demand', 'ADR']

# %%
new_df
# Out:
#      Year  Week  Demand    ADR
# 0    2015    27    31.0   31.0
# 1    2015    28    49.0   49.0
# 2    2015    29    64.0   64.0
# 3    2015    30    58.0   58.0
# 4    2015    31    64.0   64.0
# ..    ...   ...     ...    ...
# 110  2017    31   111.0  111.0
# 111  2017    32    93.0   93.0
# 112  2017    33   124.0  124.0
# 113  2017    34    97.0   97.0
# 114  2017    35    79.0   79.0
#
# [115 rows x 4 columns]

# %%
new_df.shape
# Out:
# (115, 4)

# %%
new_df[['Demand', 'ADR']]
# Out:
#      Demand    ADR
# 0      31.0   31.0
# 1      49.0   49.0
# 2      64.0   64.0
# 3      58.0   58.0
# 4      64.0   64.0
# ..      ...    ...
# 110   111.0  111.0
# 111    93.0   93.0
# 112   124.0  124.0
# 113    97.0   97.0
# 114    79.0   79.0
#
# [115 rows x 2 columns]

# %% [markdown]
# ### Creating Sequences

# %%
# split a univariate sequence into samples
def split_sequence(sequence, n_steps):
	X, y = list(), list()
	for i in range(len(sequence)):
		# find the end of this pattern
		end_ix = i + n_steps
		# check if we are beyond the sequence
		if end_ix > len(sequence)-1:
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix][0]
		X.append(seq_x)
		y.append(seq_y)
	return np.asarray(X), np.asarray(y)

# %%
np.asarray(df_lstm)
# Out:
# array([ 31.,  49.,  64.,  58.,  64.,  53.,  51.,  66.,  70.,  59.,  54.,
#         51.,  35.,  44.,  32.,  34.,  38.,  41.,  27.,   8.,  37.,  41.,
#         21.,  16.,   8.,  49.,  16.,   7.,  22.,  19.,   6.,   8.,  35.,
#         22.,  17.,  35.,  34.,  32.,  54.,  68.,  61.,  33.,  45.,  31.,
#         48.,  58.,  25.,  63.,  48.,  96.,  90.,  77.,  80.,  64.,  63.,
#         93., 101.,  67., 117., 110., 110.,  76.,  68.,  53.,  52.,  80.,
#         53.,  42.,  32.,  82.,  92.,  98., 100.,  70.,  37.,  30.,  31.,
#         52.,  91.,  55.,  68.,  53.,  37.,  69.,  64.,  67.,  68.,  85.,
#         28.,  49.,  42.,  27.,  70.,  64., 141.,  47.,  51.,  79.,  69.,
#         55.,  83.,  95.,  66.,  86.,  96.,  91.,  69., 101.,  93., 100.,
#        111.,  93., 124.,  97.,  79.])

# %%
n_steps = 10
n_features = 2

# %%
X, y = split_sequence(np.asarray(new_df[['Demand','ADR']]), n_steps)

# %% [raw]
# X, y = split_sequence(np.asarray(df_lstm), 5)

# %%
X = X.reshape((X.shape[0], X.shape[1], n_features))

# %%
X.shape
# Out:
# (105, 10, 2)

# %%
y
# Out:
# array([ 54.,  51.,  35.,  44.,  32.,  34.,  38.,  41.,  27.,   8.,  37.,
#         41.,  21.,  16.,   8.,  49.,  16.,   7.,  22.,  19.,   6.,   8.,
#         35.,  22.,  17.,  35.,  34.,  32.,  54.,  68.,  61.,  33.,  45.,
#         31.,  48.,  58.,  25.,  63.,  48.,  96.,  90.,  77.,  80.,  64.,
#         63.,  93., 101.,  67., 117., 110., 110.,  76.,  68.,  53.,  52.,
#         80.,  53.,  42.,  32.,  82.,  92.,  98., 100.,  70.,  37.,  30.,
#         31.,  52.,  91.,  55.,  68.,  53.,  37.,  69.,  64.,  67.,  68.,
#         85.,  28.,  49.,  42.,  27.,  70.,  64., 141.,  47.,  51.,  79.,
#         69.,  55.,  83.,  95.,  66.,  86.,  96.,  91.,  69., 101.,  93.,
#        100., 111.,  93., 124.,  97.,  79.])

# %% [markdown]
# ### Training Testing Split

# %%
X_train = X[0:80]
X_test = X[80:]
y_train = y[0:80]
y_test = y[80:]

# %% [markdown]
# ### LSTM Model

# %%
# define model
model = Sequential()
model.add(LSTM(50, kernel_regularizer=regularizers.l2(0.01), activation='relu', input_shape=(n_steps, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
# Out:
# WARNING:tensorflow:From C:\Users\mahee\.conda\envs\FYP\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\mahee\.conda\envs\FYP\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\mahee\.conda\envs\FYP\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\mahee\.conda\envs\FYP\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# fit model
history = model.fit(X_train, y_train, epochs=300, verbose=0, validation_data=(X_test, y_test))
# Out:
# WARNING:tensorflow:From C:\Users\mahee\.conda\envs\FYP\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\mahee\.conda\envs\FYP\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From C:\Users\mahee\.conda\envs\FYP\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.

# %% [markdown]
# ### Checking History

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#        val_loss      loss  epoch
# 295  753.887146  2.162305    295
# 296  742.722778  2.004070    296
# 297  749.372620  1.909193    297
# 298  737.308044  2.063558    298
# 299  731.905762  1.971563    299

# %%
hist.plot()

# %% [markdown]
# ### Prediction

# %% [raw]
# yhat = model.predict(X_test, verbose=0)

# %% [raw]
# yhat.shape

# %% [raw]
# y_test=y_test.reshape(y_test.shape[0],1)

# %% [raw]
# y_test.shape

# %% [raw]
# test_df = new_df[0:110]

# %% [raw]
# test_df['Estimated'] = yhat

# %% [raw]
# test_df['Observed'] = y

# %% [raw]
# test_df

# %%
yhat = model.predict(X_test, verbose=0)
y_test=y_test.reshape(y_test.shape[0],1)

sns.set(rc={'figure.figsize':(17, 10)})
fig, ax = plt.subplots()
ax.plot(y_test, marker='.', linestyle='-', linewidth=0.5, label='Observed')
ax.plot(yhat, marker='.', markersize=8, linestyle='-', label='Estimated')
ax.set_ylabel('Water Height')
ax.legend();
